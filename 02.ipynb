# %%
# %matplotlib inline

import gc
import os
import sys
import pandas as pd
import numpy as np
import tqdm
import seaborn as sns
from scipy.stats import mode

from catboost import CatBoostClassifier, Pool
from catboost import Pool, EShapCalcType, EFeaturesSelectionAlgorithm
from sklearn.model_selection import cross_val_score
from sklearn.metrics import recall_score, precision_score
import platform
from collections import Counter
from sklearn.metrics import recall_score, matthews_corrcoef
from lightgbm import LGBMClassifier, log_evaluation
from lightgbm import early_stopping

import matplotlib
import matplotlib.pyplot as plt 

from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import roc_auc_score, matthews_corrcoef, accuracy_score
from sklearn.metrics import recall_score, precision_score
from sklearn.metrics import classification_report
from scipy import stats

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer


#from skopt.space import Real, Categorical, Integer
#from skopt.utils import use_named_args
#from skopt import gp_minimize


pd.set_option('display.max_columns', None)

# если у вас есть CUDA, то она понадобится там для экспериментов в catboost
os.environ["CUDA_VISIBLE_DEVICES"] = '0'

task_type = 'GPU'
if platform.node() == 'VLAD2016':
    task_type = 'CPU'
    
import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)
warnings.simplefilter(action = 'ignore', category = DeprecationWarning)
warnings.simplefilter(action = 'ignore', category = UserWarning)
warnings.simplefilter(action = 'ignore', category = RuntimeWarning)
warnings.filterwarnings("ignore", message = "numpy.dtype size changed")
warnings.filterwarnings("ignore", message = "numpy.ufunc size changed")
pd.options.mode.chained_assignment = None

DEBUG = False
targets = [
    'Релевантность', 
    'Таксономия релевантные', 
    'Таксономия не релевантные', 
    'Длина отзыва', 
    'Ценности'
]

target = 'Таксономия релевантные'

# %%
dtrain = pd.read_csv('../input/train_dataset_train.csv')
dtrain.head(3)
# Out:
#    RecordNo           Название книги         Автор  \
# 0      6145  Зулейха открывает глаза  Гузель Яхина
# 1      7006  Зулейха открывает глаза  Гузель Яхина
# 2      1124                 Дети мои  Гузель Яхина
#
#                                     Ссылка на литрес  Рейтинг  \
# 0  https://www.litres.ru/guzel-yahina/zuleyha-otk...      4.7
# 1  https://www.litres.ru/guzel-yahina/zuleyha-otk...      4.6
# 2       https://www.litres.ru/guzel-yahina/deti-moi/      4.4
#
#    Количество оценок  Количество отзывов    Имя читателя  \
# 0               3922                 408   Айгуль Ляпина
# 1              24719                2103          Olga T
# 2               8032                 702  Кирилл Чириков
#
#    Оценка книги читателем (из 5 баллов)  \
# 0                                   5.0
# 1                                   5.0
# 2                                   5.0
#
#                                                Отзыв  Лайки на отзыв  \
# 0  Рекомендую книгу в прочтению/прослушиванию. Ес...               0
# 1  Удивительно, что сейчас возникает ТАКАЯ литера...               0
# 2  Душевно, жизненно, чувственно, проникновенно!!...               0
#
#    Дислайки на отзыв  Релевантность  Таксономия релевантные  \
# 0                  3              0                       0
# 1                  1              0                       0
# 2                  0              0                       1
#
#    Таксономия не релевантные  Длина отзыва  Ценности
# 0                          0             0         0
# 1                          0             0         1
# 2                          0             0         1

# %%
for u in sorted(dtrain[target].unique()):
    print(u, dtrain[dtrain[target] == u].shape[0])
# Out:
# 0 2360
# 1 2479

# %%
dtest = pd.read_csv(
    '../input/test_dataset_test.csv',
    na_values = 'NULL'
)
dtest.head(3)
# Out:
#    RecordNo Название книги               Автор  \
# 0      3366       Дети мои        Гузель Яхина
# 1      3952          Текст  Дмитрий Глуховский
# 2      6852          Текст  Дмитрий Глуховский
#
#                                     Ссылка на литрес  Рейтинг  \
# 0       https://www.litres.ru/guzel-yahina/deti-moi/      4.4
# 1  https://www.litres.ru/dmitriy-gluhovskiy/tekst...      4.5
# 2    https://www.litres.ru/dmitriy-gluhovskiy/tekst/      4.4
#
#    Количество оценок  Количество отзывов        Имя читателя  \
# 0               8032                 702     Марина Ефимкина
# 1               1923                 246            alexvarp
# 2               7276                 622  fb_154207611938008
#
#    Оценка книги читателем (из 5 баллов)  \
# 0                                   5.0
# 1                                   5.0
# 2                                   5.0
#
#                                                Отзыв  Лайки на отзыв  \
# 0  Настоящая глубокая книга, коих сейчас очень не...               2
# 1  Одна из лучших книг прочитанных за последние г...               1
# 2  Тот случай, когда невозможно пройти мимо, не о...               0
#
#    Дислайки на отзыв
# 0                  0
# 1                  0
# 2                  0

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

enc = OneHotEncoder(handle_unknown = 'ignore')
le  = LabelEncoder()
L = dtrain.shape[0]
categorical_columns = [
    'Название книги', 'Автор', 'Имя читателя'
]

for u in categorical_columns:
    print(u, len(dtrain[u].unique()))
    
    if len(dtrain[u].unique()) < 1:
        df = pd.DataFrame(pd.concat([dtrain[u], dtest[u]], axis = 0))
        df[u] = df[u].fillna('none')
        df[u] = df[u].astype(str)
        df[u] = df[u] + '_' + u
        
        temp = enc.fit_transform(df[u].values.reshape(-1, 1)).toarray()
        for i in range(temp.shape[1]):
            n = u + '_' + str(i)
            dtrain[n] = temp[:, i][:L]
            dtest[n] = temp[:, i][L:]
            if n not in use:
                use.append(n)        
        if u in use:
            use.remove(u)       
    
        dtrain.drop(u, axis = 1, inplace = True)
        dtest.drop(u, axis = 1, inplace = True)
    
    else:
        df = pd.DataFrame(pd.concat([dtrain[u], dtest[u]], axis = 0))
        df[u] = df[u].fillna('none')
        df[u] = df[u].astype(str)
        le.fit(df[u].values.ravel())
        temp = le.transform(df[u].values.ravel())
        dtrain[u] = temp[:L]
        dtest[u]  = temp[L:]        
    
gc.collect()
# Out:
# Название книги 103
# Автор 59
# Имя читателя 4263
# 36

# %%
use = [f for f in dtrain.columns if f not in targets]
use = [f for f in use if f not in ['Ссылка на литрес']]

# %%
vectorizer = TfidfVectorizer(
    lowercase = True, 
    preprocessor = None, 
    tokenizer = None, 
    analyzer = 'char', 
    stop_words = None, 
    token_pattern = None, 
    ngram_range = (1, 5), 
    max_df = 1.0, 
    min_df = 1, 
    max_features = 50000,
)
train = vectorizer.fit_transform(dtrain['Отзыв'].values)
test  = vectorizer.transform(dtest['Отзыв'].values)

# %%
train.shape
# Out:
# (4839, 50000)

# %%
from scipy.sparse import coo_matrix, vstack, hstack

for u in use:
    if u != 'Отзыв':
        train = hstack([train, dtrain[u][:,None]])
        test  = hstack([test, dtest[u][:,None]])

# %%
X_train, X_valid, y_train, y_valid = train_test_split(
    train,
    dtrain[target],
    test_size = 0.1, 
    random_state = 2,
    stratify = dtrain[target]
)

print(X_train.shape, X_valid.shape)
print(y_train.shape, y_valid.shape)
# Out:
# (4355, 50010) (484, 50010)
# (4355,) (484,)

# %%
train = train.tocsr()
test = test.tocsr()
cols = train.max(axis=0)
cols
# Out:
# <1x50010 sparse matrix of type '<class 'numpy.float64'>'
# 	with 50010 stored elements in COOrdinate format>

# %% [raw]
# from lightgbm import LGBMClassifier, log_evaluation
# from lightgbm import early_stopping
# from sklearn.metrics import roc_auc_score, matthews_corrcoef
# from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
#
# #####
# def get_feat_adapt(xtrain, xtest, thr, n_cals):
#
#     trn = np.ones(xtrain.shape[0])
#     tst = np.zeros(xtest.shape[0])
#
#     trg = np.concatenate((trn, tst), axis = 0)
#
#     all_data = vstack([xtrain, xtest])
#     all_data = all_data.tocsr()
#
#     del xtrain, xtest
#
#     df = pd.DataFrame(columns = ['feat', 'auc'])
#
#     for i in range(n_cals):
#         feature_importances = 0
#         score = []
#         SEEDS = 1
#         xuse = range(all_data.shape[1])
#
#         for seed in range(SEEDS):
#             skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = seed)
#
#             for i, (train_index, test_index) in enumerate(skf.split(all_data, trg)):
#                 X_train, X_val = all_data[train_index], all_data[test_index]
#                 y_train, y_valid = trg[train_index], trg[test_index]
#
#                 model = CatBoostClassifier(
#                     iterations = 1000000,
#                     depth = 5,
#                     learning_rate = 0.1,
#                     reg_lambda = 0.1,
#                     loss_function = 'MultiClass',
#                     #eval_metric = 'TotalF1:average=Macro',
#                     #eval_metric = 'MC',
#                     #loss_function = 'CrossEntropy',
#                     #eval_metric = 'Recall',
#                     #eval_metric = AccuracyMetric(),
#                     task_type = task_type,
#                     random_state = seed,
#                     early_stopping_rounds = 100,
#                     verbose = False,
#                 )
#                 model.fit(
#                     X_train,
#                     y_train,
#                     eval_set = (X_val, y_valid),
#                 )
#                 feature_importances += model.feature_importances_
#                 y_pred = model.predict_proba(X_val)[:, 1]
#                 sc = roc_auc_score(y_valid, y_pred)
#                 score.append(sc)
#
#         feature_imp = pd.DataFrame({'Value':feature_importances,'Feature':xuse})
#         feature_imp.sort_values(by = ['Value'], inplace = True, ascending = False)
#         feature_imp.reset_index(drop = True, inplace = True)
#         feat = feature_imp['Feature'].head(1).values[0]
#         sc = np.mean(score)
#
#         print(feat, sc)
#
#         all_data = hstack([all_data[:,0:feat], all_data[:,feat+1:]])
#         all_data = all_data.tocsr()
#         print(all_data.shape)
#
#         L = df.shape[0]
#         df.loc[L, 'feat'] = feat
#         df.loc[L, 'auc'] = sc
#
#         if sc < thr:
#             print('stop in score')
#             break
#
#     return(df)
#
#
# df = get_feat_adapt(train, test, 0.5, 3)
#
# df

# %% [raw]
# stop

# %%
SEEDS = 3
iterations = 10000
early_stopping_rounds = 500
preds = []
    
    
for seed in range(SEEDS):
    
    skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = seed)
    
    for train_index, test_index in skf.split(dtrain, dtrain[target]):
        
        X_train, X_valid = train[train_index], train[test_index]
        y_train, y_valid = dtrain[target].loc[train_index], dtrain[target].loc[test_index]       
        
        model = CatBoostClassifier(
            iterations = iterations,
            depth = 5, 
            learning_rate = 0.1,
            reg_lambda = 0.1,
            loss_function = 'MultiClass',
            #eval_metric = 'TotalF1:average=Macro',
            #eval_metric = 'MC', 
            #loss_function = 'CrossEntropy',
            #eval_metric = 'Recall',
            #eval_metric = AccuracyMetric(),
            task_type = task_type,
            random_state = seed,
            early_stopping_rounds = early_stopping_rounds,
            verbose = 500,     
        )
        model.fit(
            X_train,
            y_train,
            eval_set = (X_valid, y_valid),
        ) 
        preds.append(model.predict(test))
    
preds = stats.mode(preds)[0][0]
dtest[target] = preds
# Out:
# Warning: less than 75% gpu memory available for training. Free: 2842.0625 Total: 5946.5625
# 0:	learn: 0.6327639	test: 0.6354899	best: 0.6354899 (0)	total: 166ms	remaining: 27m 39s
# 500:	learn: 0.0274626	test: 0.1325872	best: 0.1323698 (492)	total: 38.3s	remaining: 12m 6s
# 1000:	learn: 0.0067557	test: 0.1348814	best: 0.1305351 (585)	total: 1m 15s	remaining: 11m 20s
# bestTest = 0.1305351415
# bestIteration = 585
# Shrink model to first 586 iterations.
# 0:	learn: 0.6338053	test: 0.6337294	best: 0.6337294 (0)	total: 149ms	remaining: 24m 52s
# 500:	learn: 0.0308338	test: 0.1082068	best: 0.1075954 (495)	total: 38.7s	remaining: 12m 13s
# 1000:	learn: 0.0076646	test: 0.0982942	best: 0.0978538 (974)	total: 1m 16s	remaining: 11m 26s
# 1500:	learn: 0.0028299	test: 0.1031865	best: 0.0970419 (1050)	total: 1m 53s	remaining: 10m 43s
# bestTest = 0.09704187094
# bestIteration = 1050
# Shrink model to first 1051 iterations.
# 0:	learn: 0.6333555	test: 0.6350420	best: 0.6350420 (0)	total: 141ms	remaining: 23m 33s
# 500:	learn: 0.0297013	test: 0.1223240	best: 0.1223240 (500)	total: 38.6s	remaining: 12m 11s
# 1000:	learn: 0.0075554	test: 0.1228711	best: 0.1188517 (737)	total: 1m 16s	remaining: 11m 25s
# bestTest = 0.1188517011
# bestIteration = 737
# Shrink model to first 738 iterations.
# 0:	learn: 0.6340196	test: 0.6319835	best: 0.6319835 (0)	total: 149ms	remaining: 24m 46s
# 500:	learn: 0.0287837	test: 0.1130650	best: 0.1128928 (497)	total: 39.2s	remaining: 12m 23s
# 1000:	learn: 0.0070856	test: 0.1074856	best: 0.1058192 (853)	total: 1m 17s	remaining: 11m 38s
# bestTest = 0.1058191662
# bestIteration = 853
# Shrink model to first 854 iterations.
# 0:	learn: 0.6341950	test: 0.6333977	best: 0.6333977 (0)	total: 138ms	remaining: 22m 59s
# 500:	learn: 0.0283679	test: 0.1085595	best: 0.1084188 (494)	total: 38.5s	remaining: 12m 9s
# 1000:	learn: 0.0070780	test: 0.1077977	best: 0.1047407 (621)	total: 1m 16s	remaining: 11m 23s
# bestTest = 0.1047406991
# bestIteration = 621
# Shrink model to first 622 iterations.
# 0:	learn: 0.6347334	test: 0.6346647	best: 0.6346647 (0)	total: 141ms	remaining: 23m 26s
# 500:	learn: 0.0276863	test: 0.1292758	best: 0.1289116 (493)	total: 40.5s	remaining: 12m 47s
# 1000:	learn: 0.0068121	test: 0.1341333	best: 0.1279191 (777)	total: 1m 19s	remaining: 11m 55s
# bestTest = 0.1279190867
# bestIteration = 777
# Shrink model to first 778 iterations.
# 0:	learn: 0.6347669	test: 0.6367978	best: 0.6367978 (0)	total: 141ms	remaining: 23m 25s
# 500:	learn: 0.0306049	test: 0.1186578	best: 0.1186567 (495)	total: 38.7s	remaining: 12m 13s
# 1000:	learn: 0.0074064	test: 0.1127799	best: 0.1104068 (796)	total: 1m 18s	remaining: 11m 43s
# bestTest = 0.1104068126
# bestIteration = 796
# Shrink model to first 797 iterations.
# 0:	learn: 0.6329600	test: 0.6360919	best: 0.6360919 (0)	total: 150ms	remaining: 25m
# 500:	learn: 0.0275991	test: 0.1345048	best: 0.1337220 (493)	total: 39.3s	remaining: 12m 24s
# 1000:	learn: 0.0069411	test: 0.1388036	best: 0.1321127 (563)	total: 1m 19s	remaining: 11m 54s
# bestTest = 0.1321127395
# bestIteration = 563
# Shrink model to first 564 iterations.
# 0:	learn: 0.6356663	test: 0.6325092	best: 0.6325092 (0)	total: 142ms	remaining: 23m 39s
# 500:	learn: 0.0296406	test: 0.1080963	best: 0.1077724 (488)	total: 38.5s	remaining: 12m 10s
# 1000:	learn: 0.0071684	test: 0.1092767	best: 0.1046525 (676)	total: 1m 16s	remaining: 11m 24s
# bestTest = 0.1046524836
# bestIteration = 676
# Shrink model to first 677 iterations.
# 0:	learn: 0.6304386	test: 0.6327697	best: 0.6327697 (0)	total: 147ms	remaining: 24m 30s
# 500:	learn: 0.0297541	test: 0.1096177	best: 0.1096177 (500)	total: 38.4s	remaining: 12m 9s
# 1000:	learn: 0.0075507	test: 0.1051218	best: 0.1027886 (803)	total: 1m 15s	remaining: 11m 20s
# bestTest = 0.1027886076
# bestIteration = 803
# Shrink model to first 804 iterations.
# 0:	learn: 0.6311455	test: 0.6333338	best: 0.6333338 (0)	total: 142ms	remaining: 23m 41s
# 500:	learn: 0.0259434	test: 0.1613962	best: 0.1602503 (437)	total: 42s	remaining: 13m 15s
# bestTest = 0.1602502618
# bestIteration = 437
# Shrink model to first 438 iterations.
# 0:	learn: 0.6313519	test: 0.6331570	best: 0.6331570 (0)	total: 145ms	remaining: 24m 11s
# 500:	learn: 0.0282863	test: 0.1485428	best: 0.1485428 (500)	total: 43.1s	remaining: 13m 36s
# 1000:	learn: 0.0066935	test: 0.1528575	best: 0.1468163 (593)	total: 1m 26s	remaining: 12m 53s
# bestTest = 0.1468162852
# bestIteration = 593
# Shrink model to first 594 iterations.
# 0:	learn: 0.6319297	test: 0.6319085	best: 0.6319085 (0)	total: 160ms	remaining: 26m 39s
# 500:	learn: 0.0315236	test: 0.0889786	best: 0.0889786 (500)	total: 42.8s	remaining: 13m 31s
# 1000:	learn: 0.0082833	test: 0.0786483	best: 0.0775542 (854)	total: 1m 24s	remaining: 12m 36s
# 1500:	learn: 0.0029585	test: 0.0796734	best: 0.0772784 (1280)	total: 2m 5s	remaining: 11m 49s
# bestTest = 0.07727838942
# bestIteration = 1280
# Shrink model to first 1281 iterations.
# 0:	learn: 0.6335001	test: 0.6294752	best: 0.6294752 (0)	total: 161ms	remaining: 26m 47s
# 500:	learn: 0.0315726	test: 0.0898087	best: 0.0897909 (499)	total: 42.6s	remaining: 13m 27s
# 1000:	learn: 0.0082973	test: 0.0797560	best: 0.0790943 (801)	total: 1m 24s	remaining: 12m 41s
# 1500:	learn: 0.0030013	test: 0.0813123	best: 0.0789163 (1032)	total: 2m 6s	remaining: 11m 53s
# bestTest = 0.07891626594
# bestIteration = 1032
# Shrink model to first 1033 iterations.
# 0:	learn: 0.6315637	test: 0.6327106	best: 0.6327106 (0)	total: 136ms	remaining: 22m 42s
# 500:	learn: 0.0288010	test: 0.1046217	best: 0.1044456 (494)	total: 42.3s	remaining: 13m 21s
# 1000:	learn: 0.0072462	test: 0.0970762	best: 0.0951127 (830)	total: 1m 23s	remaining: 12m 30s
# bestTest = 0.09511268718
# bestIteration = 830
# Shrink model to first 831 iterations.

# %%
dtest[['RecordNo'] + [target]].head()
# Out:
#    RecordNo  Таксономия релевантные
# 0      3366                       0
# 1      3952                       1
# 2      6852                       0
# 3      4586                       0
# 4      4677                       1

# %%
dtest[['RecordNo'] + [target]].to_csv('02.csv', index = False)

# %%
for u in sorted(dtest[target].unique()):
    print(u, dtest[dtest[target] == u].shape[0])
# Out:
# 0 1100
# 1 975

# %% [markdown]
# https://lk.hacks-ai.ru/758289/champ
