# %%
# %matplotlib inline

import gc
import os
import sys
import pandas as pd
import numpy as np
import tqdm
import seaborn as sns
from scipy.stats import mode

from catboost import CatBoostClassifier, Pool
from catboost import Pool, EShapCalcType, EFeaturesSelectionAlgorithm
from sklearn.model_selection import cross_val_score
from sklearn.metrics import recall_score, precision_score
import platform
from collections import Counter
from sklearn.metrics import recall_score, matthews_corrcoef
from lightgbm import LGBMClassifier, log_evaluation
from lightgbm import early_stopping

import matplotlib
import matplotlib.pyplot as plt 

from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.metrics import roc_auc_score, matthews_corrcoef, accuracy_score
from sklearn.metrics import recall_score, precision_score
from sklearn.metrics import classification_report
from scipy import stats

from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer

#from skopt.space import Real, Categorical, Integer
#from skopt.utils import use_named_args
#from skopt import gp_minimize


pd.set_option('display.max_columns', None)

# если у вас есть CUDA, то она понадобится там для экспериментов в catboost
os.environ["CUDA_VISIBLE_DEVICES"] = '0'

task_type = 'GPU'
if platform.node() == 'VLAD2016':
    task_type = 'CPU'
    
import warnings
warnings.simplefilter(action = 'ignore', category = FutureWarning)
warnings.simplefilter(action = 'ignore', category = DeprecationWarning)
warnings.simplefilter(action = 'ignore', category = UserWarning)
warnings.simplefilter(action = 'ignore', category = RuntimeWarning)
warnings.filterwarnings("ignore", message = "numpy.dtype size changed")
warnings.filterwarnings("ignore", message = "numpy.ufunc size changed")
pd.options.mode.chained_assignment = None

DEBUG = False
targets = [
    'Релевантность', 
    'Таксономия релевантные',
    'Таксономия не релевантные',
    'Длина отзыва', 
    'Ценности'
]

target = 'Релевантность'

# %%
dtrain = pd.read_csv('../input/train_dataset_train.csv')
dtrain.head(3)
# Out:
#    RecordNo           Название книги         Автор  \
# 0      6145  Зулейха открывает глаза  Гузель Яхина
# 1      7006  Зулейха открывает глаза  Гузель Яхина
# 2      1124                 Дети мои  Гузель Яхина
#
#                                     Ссылка на литрес  Рейтинг  \
# 0  https://www.litres.ru/guzel-yahina/zuleyha-otk...      4.7
# 1  https://www.litres.ru/guzel-yahina/zuleyha-otk...      4.6
# 2       https://www.litres.ru/guzel-yahina/deti-moi/      4.4
#
#    Количество оценок  Количество отзывов    Имя читателя  \
# 0               3922                 408   Айгуль Ляпина
# 1              24719                2103          Olga T
# 2               8032                 702  Кирилл Чириков
#
#    Оценка книги читателем (из 5 баллов)  \
# 0                                   5.0
# 1                                   5.0
# 2                                   5.0
#
#                                                Отзыв  Лайки на отзыв  \
# 0  Рекомендую книгу в прочтению/прослушиванию. Ес...               0
# 1  Удивительно, что сейчас возникает ТАКАЯ литера...               0
# 2  Душевно, жизненно, чувственно, проникновенно!!...               0
#
#    Дислайки на отзыв  Релевантность  Таксономия релевантные  \
# 0                  3              0                       0
# 1                  1              0                       0
# 2                  0              0                       1
#
#    Таксономия не релевантные  Длина отзыва  Ценности
# 0                          0             0         0
# 1                          0             0         1
# 2                          0             0         1

# %%
dtrain.isna().sum()
# Out:
# RecordNo                                  0
# Название книги                            0
# Автор                                     0
# Ссылка на литрес                          0
# Рейтинг                                   0
# Количество оценок                         0
# Количество отзывов                        0
# Имя читателя                              0
# Оценка книги читателем (из 5 баллов)    769
# Отзыв                                     0
# Лайки на отзыв                            0
# Дислайки на отзыв                         0
# Релевантность                             0
# Таксономия релевантные                    0
# Таксономия не релевантные                 0
# Длина отзыва                              0
# Ценности                                  0
# dtype: int64

# %%
for u in sorted(dtrain[target].unique()):
    print(u, dtrain[dtrain[target] == u].shape[0])
# Out:
# 0 3781
# 1 1058

# %%
dtest = pd.read_csv(
    '../input/test_dataset_test.csv',
    na_values = 'NULL'
)
dtest.head(3)
# Out:
#    RecordNo Название книги               Автор  \
# 0      3366       Дети мои        Гузель Яхина
# 1      3952          Текст  Дмитрий Глуховский
# 2      6852          Текст  Дмитрий Глуховский
#
#                                     Ссылка на литрес  Рейтинг  \
# 0       https://www.litres.ru/guzel-yahina/deti-moi/      4.4
# 1  https://www.litres.ru/dmitriy-gluhovskiy/tekst...      4.5
# 2    https://www.litres.ru/dmitriy-gluhovskiy/tekst/      4.4
#
#    Количество оценок  Количество отзывов        Имя читателя  \
# 0               8032                 702     Марина Ефимкина
# 1               1923                 246            alexvarp
# 2               7276                 622  fb_154207611938008
#
#    Оценка книги читателем (из 5 баллов)  \
# 0                                   5.0
# 1                                   5.0
# 2                                   5.0
#
#                                                Отзыв  Лайки на отзыв  \
# 0  Настоящая глубокая книга, коих сейчас очень не...               2
# 1  Одна из лучших книг прочитанных за последние г...               1
# 2  Тот случай, когда невозможно пройти мимо, не о...               0
#
#    Дислайки на отзыв
# 0                  0
# 1                  0
# 2                  0

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

enc = OneHotEncoder(handle_unknown = 'ignore')
le  = LabelEncoder()
L = dtrain.shape[0]
categorical_columns = [
    'Название книги', 'Автор', 'Имя читателя'
]

for u in categorical_columns:
    print(u, len(dtrain[u].unique()))
    
    if len(dtrain[u].unique()) < 1:
        df = pd.DataFrame(pd.concat([dtrain[u], dtest[u]], axis = 0))
        df[u] = df[u].fillna('none')
        df[u] = df[u].astype(str)
        df[u] = df[u] + '_' + u
        
        temp = enc.fit_transform(df[u].values.reshape(-1, 1)).toarray()
        for i in range(temp.shape[1]):
            n = u + '_' + str(i)
            dtrain[n] = temp[:, i][:L]
            dtest[n] = temp[:, i][L:]
            if n not in use:
                use.append(n)        
        if u in use:
            use.remove(u)       
    
        dtrain.drop(u, axis = 1, inplace = True)
        dtest.drop(u, axis = 1, inplace = True)
    
    else:
        df = pd.DataFrame(pd.concat([dtrain[u], dtest[u]], axis = 0))
        df[u] = df[u].fillna('none')
        df[u] = df[u].astype(str)
        le.fit(df[u].values.ravel())
        temp = le.transform(df[u].values.ravel())
        dtrain[u] = temp[:L]
        dtest[u]  = temp[L:]        
    
gc.collect()
# Out:
# Название книги 103
# Автор 59
# Имя читателя 4263
# 119

# %%
use = [f for f in dtrain.columns if f not in targets]
use = [f for f in use if f not in ['Ссылка на литрес']]

# %%
use
# Out:
# ['RecordNo',
#  'Название книги',
#  'Автор',
#  'Рейтинг',
#  'Количество оценок',
#  'Количество отзывов',
#  'Имя читателя',
#  'Оценка книги читателем (из 5 баллов)',
#  'Отзыв',
#  'Лайки на отзыв',
#  'Дислайки на отзыв']

# %%
text_processing = {
            "tokenizers" : [{
                "tokenizer_id" : "Space",
                "separator_type" : "ByDelimiter",
                "delimiter" : " "
            }],

            "dictionaries" : [{
                "dictionary_id" : "BiGram",
                "token_level_type": "Letter",
                "max_dictionary_size" : "150000",
                "occurrence_lower_bound" : "1",
                "gram_order" : "2"
            },{
                "dictionary_id" : "Trigram",
                "max_dictionary_size" : "150000",
                "token_level_type": "Letter",
                "occurrence_lower_bound" : "1",
                "gram_order" : "3"
            },{
                "dictionary_id" : "Fourgram",
                "max_dictionary_size" : "150000",
                "token_level_type": "Letter",
                "occurrence_lower_bound" : "1",
                "gram_order" : "4"
            },{
                "dictionary_id" : "Fivegram",
                "max_dictionary_size" : "150000",
                "token_level_type": "Letter",
                "occurrence_lower_bound" : "1",
                "gram_order" : "5"
            },{
                "dictionary_id" : "Sixgram",
                "max_dictionary_size" : "150000",
                "token_level_type": "Letter",
            "occurrence_lower_bound" : "1",
            "gram_order" : "6"
            }
            ],

            "feature_processing" : {
                "default" : [
                        {
                        "dictionaries_names" : ["BiGram", "Trigram", "Fourgram", "Fivegram", "Sixgram"],
                        "feature_calcers" : ["BoW"],
                        "tokenizers_names" : ["Space"]
                    },
                        {
                    "dictionaries_names" : ["BiGram", "Trigram", "Fourgram", "Fivegram", "Sixgram"],
                    "feature_calcers" : ["NaiveBayes"],
                    "tokenizers_names" : ["Space"]
                },{
                    "dictionaries_names" : [ "BiGram", "Trigram", "Fourgram", "Fivegram", "Sixgram"],
                    "feature_calcers" : ["BM25"],
                    "tokenizers_names" : ["Space"]
                },
                ],
            }
        }

# %%
SEEDS = 3
iterations = 10000
early_stopping_rounds = 500
preds = []
score = []
    
    
for seed in range(SEEDS):
    
    skf = StratifiedKFold(n_splits = 5, shuffle = True, random_state = seed)
    
    for train_index, test_index in skf.split(dtrain, dtrain[target]):
        X_train, X_valid = dtrain.loc[train_index], dtrain.loc[test_index]       
        
        model = CatBoostClassifier(
            text_features = ['Отзыв'],
            iterations = iterations,
            depth = 5, 
            learning_rate = 0.1,
            reg_lambda = 0.1,
            loss_function = 'MultiClass',
            task_type = task_type,
            random_state = seed,
            early_stopping_rounds = early_stopping_rounds,
            verbose = 500,
            text_processing = text_processing        
        )
        model.fit(
            X_train[use],
            X_train[target],
            eval_set = (X_valid[use], X_valid[target]),
        ) 
        preds.append(model.predict(dtest[use]))
        
        y_pred = model.predict(X_valid[use]).ravel()
        sc = recall_score(X_valid[target], y_pred, average = 'weighted')
        print(sc, '\n')
        score.append(sc)
    
preds = stats.mode(preds)[0][0]
dtest[target] = preds

print('\n', np.mean(score))
# Out:
# 0:	learn: 0.6535784	test: 0.6537008	best: 0.6537008 (0)	total: 10.7ms	remaining: 1m 47s
# 500:	learn: 0.1291376	test: 0.4026256	best: 0.3937478 (275)	total: 2.45s	remaining: 46.4s
# bestTest = 0.3937478184
# bestIteration = 275
# Shrink model to first 276 iterations.
# 0.8233471074380165
#
# 0:	learn: 0.6519565	test: 0.6549256	best: 0.6549256 (0)	total: 8.07ms	remaining: 1m 20s
# 500:	learn: 0.1259081	test: 0.4107228	best: 0.4018653 (152)	total: 2.56s	remaining: 48.6s
# bestTest = 0.4018652735
# bestIteration = 152
# Shrink model to first 153 iterations.
# 0.7985537190082644
#
# 0:	learn: 0.6525651	test: 0.6551483	best: 0.6551483 (0)	total: 8.8ms	remaining: 1m 28s
# 500:	learn: 0.1283016	test: 0.4078608	best: 0.3958625 (160)	total: 2.43s	remaining: 46.1s
# bestTest = 0.3958625478
# bestIteration = 160
# Shrink model to first 161 iterations.
# 0.8119834710743802
#
# 0:	learn: 0.6526703	test: 0.6513085	best: 0.6513085 (0)	total: 10.8ms	remaining: 1m 48s
# 500:	learn: 0.1277769	test: 0.3839695	best: 0.3791628 (356)	total: 2.49s	remaining: 47.3s
# bestTest = 0.379162812
# bestIteration = 356
# Shrink model to first 357 iterations.
# 0.8347107438016529
#
# 0:	learn: 0.6516255	test: 0.6520917	best: 0.6520917 (0)	total: 9.1ms	remaining: 1m 30s
# 500:	learn: 0.1283432	test: 0.4014482	best: 0.3915456 (219)	total: 2.47s	remaining: 46.9s
# bestTest = 0.3915455768
# bestIteration = 219
# Shrink model to first 220 iterations.
# 0.8210961737331954
#
# 0:	learn: 0.6518762	test: 0.6501674	best: 0.6501674 (0)	total: 7.34ms	remaining: 1m 13s
# 500:	learn: 0.1288261	test: 0.4055975	best: 0.3944115 (289)	total: 2.59s	remaining: 49.1s
# bestTest = 0.3944114811
# bestIteration = 289
# Shrink model to first 290 iterations.
# 0.8336776859504132
#
# 0:	learn: 0.6528229	test: 0.6518663	best: 0.6518663 (0)	total: 11.1ms	remaining: 1m 51s
# 500:	learn: 0.1269401	test: 0.4061621	best: 0.3963536 (195)	total: 2.48s	remaining: 47s
# bestTest = 0.3963535719
# bestIteration = 195
# Shrink model to first 196 iterations.
# 0.8223140495867769
#
# 0:	learn: 0.6513066	test: 0.6526279	best: 0.6526279 (0)	total: 7.42ms	remaining: 1m 14s
# 500:	learn: 0.1322625	test: 0.4104465	best: 0.4020725 (310)	total: 2.45s	remaining: 46.5s
# bestTest = 0.4020724967
# bestIteration = 310
# Shrink model to first 311 iterations.
# 0.8212809917355371
#
# 0:	learn: 0.6522198	test: 0.6531035	best: 0.6531035 (0)	total: 10.6ms	remaining: 1m 46s
# 500:	learn: 0.1290910	test: 0.3935003	best: 0.3903142 (395)	total: 2.45s	remaining: 46.4s
# bestTest = 0.3903142125
# bestIteration = 395
# Shrink model to first 396 iterations.
# 0.8233471074380165
#
# 0:	learn: 0.6515913	test: 0.6518396	best: 0.6518396 (0)	total: 9.81ms	remaining: 1m 38s
# 500:	learn: 0.1271891	test: 0.4034512	best: 0.3934820 (234)	total: 2.42s	remaining: 46s
# bestTest = 0.3934820386
# bestIteration = 234
# Shrink model to first 235 iterations.
# 0.8086866597724922
#
# 0:	learn: 0.6513176	test: 0.6497230	best: 0.6497230 (0)	total: 11.7ms	remaining: 1m 57s
# 500:	learn: 0.1300143	test: 0.3991581	best: 0.3893466 (87)	total: 2.58s	remaining: 49s
# bestTest = 0.389346635
# bestIteration = 87
# Shrink model to first 88 iterations.
# 0.8140495867768595
#
# 0:	learn: 0.6524247	test: 0.6537380	best: 0.6537380 (0)	total: 7.94ms	remaining: 1m 19s
# 500:	learn: 0.1239048	test: 0.4107905	best: 0.4003553 (119)	total: 2.54s	remaining: 48.1s
# bestTest = 0.4003552839
# bestIteration = 119
# Shrink model to first 120 iterations.
# 0.8233471074380165
#
# 0:	learn: 0.6514713	test: 0.6522911	best: 0.6522911 (0)	total: 7.89ms	remaining: 1m 18s
# 500:	learn: 0.1270665	test: 0.3944751	best: 0.3855727 (257)	total: 2.51s	remaining: 47.6s
# bestTest = 0.3855727014
# bestIteration = 257
# Shrink model to first 258 iterations.
# 0.8305785123966942
#
# 0:	learn: 0.6520833	test: 0.6523504	best: 0.6523504 (0)	total: 8.6ms	remaining: 1m 26s
# 500:	learn: 0.1286952	test: 0.3981933	best: 0.3885857 (232)	total: 2.54s	remaining: 48.2s
# bestTest = 0.3885856818
# bestIteration = 232
# Shrink model to first 233 iterations.
# 0.8233471074380165
#
# 0:	learn: 0.6521156	test: 0.6518445	best: 0.6518445 (0)	total: 10.4ms	remaining: 1m 44s
# 500:	learn: 0.1332201	test: 0.3928671	best: 0.3898947 (265)	total: 2.56s	remaining: 48.6s
# bestTest = 0.389894661
# bestIteration = 265
# Shrink model to first 266 iterations.
# 0.811789038262668
#
#
#  0.8201406041234

# %%
dtest[['RecordNo'] + [target]].head()
# Out:
#    RecordNo  Релевантность
# 0      3366              0
# 1      3952              0
# 2      6852              0
# 3      4586              0
# 4      4677              0

# %%
dtest[['RecordNo'] + [target]].to_csv('01.csv', index = False)

# %%
for u in sorted(dtest[target].unique()):
    print(u, dtest[dtest[target] == u].shape[0])
# Out:
# 0 1811
# 1 264

# %% [markdown]
# https://lk.hacks-ai.ru/758289/champ
